# %%
from math import log, exp
from scipy.stats import linregress
import re

f = open("price-elasticity.csv",'r')
rows = [ line.strip().split(',') for line in f ]
header = rows[0]
data = rows[1:]

weekday_ids = ['1','2','3','4','5']
weekend_ids = ['6','7']

x = 'demand quantity'
y = 'room price'

weekday_data = [[],[]]
weekend_data = [[],[]]

for row in data:
        if row[0] in weekday_ids:
                weekday_data[0].append(log(float(row[1])))
                weekday_data[1].append(log(float(re.sub(r'\$','',row[2]))))
          
        if row[0] in weekend_ids:
                weekend_data[0].append(log(float(row[1])))
                weekend_data[1].append(log(float(re.sub(r'\$','',row[2]))))
             
# weekday
wd_slope, wd_intercept, wd_r_value, p_value, std_err = linregress(weekday_data[1],weekday_data[0])
print "weekday price elasticity =", wd_slope

# weekend
we_slope, we_intercept, we_r_value, p_value, std_err = linregress(weekend_data[1],weekend_data[0])
print "weekend price elasticity =", we_slope
# Out:
# weekday price elasticity = -1.76299672428
# weekend price elasticity = -1.43691327427

# %%
import pandas as pd
weekday_df = pd.DataFrame({ 'rooms_log': weekday_data[0], 'price_log': weekday_data[1] })
weekend_df = pd.DataFrame({ 'rooms_log': weekend_data[0], 'price_log': weekend_data[1] })
weekday_est = [ exp(wd_intercept+wd_slope*log(x)) for x in arange(100,500) ]
weekend_est = [ exp(we_intercept+we_slope*log(x)) for x in arange(100,500) ]

# %%
weekday_df['price'] = weekday_df['price_log'].apply(lambda x: exp(x))
weekday_df['rooms'] = weekday_df['rooms_log'].apply(lambda x: exp(x))
weekend_df['price'] = weekend_df['price_log'].apply(lambda x: exp(x))
weekend_df['rooms'] = weekend_df['rooms_log'].apply(lambda x: exp(x))

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(weekday_df['rooms'],weekday_df['price'],'o',label='weekday')
ax.plot(weekend_df['rooms'],weekend_df['price'],'x',label='weekend')
ax.plot(weekday_est,arange(100,500),'r-',label='weekday est.')
ax.plot(weekend_est,arange(100,500),'y-',label='weekend est.')
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels)

# %%
weekend_df[:10]
# Out:
#    price_log  rooms_log   price  rooms
# 0   4.897317   7.629490  133.93   2058
# 1   5.732856   6.261492  308.85    524
# 2   5.351100   6.391917  210.84    597
# 3   5.076048   7.175490  160.14   1307
# 4   5.588297   3.135494  267.28     23
# 5   5.103458   6.487684  164.59    657
# 6   5.361104   6.311735  212.96    551
# 7   5.398298   6.919684  221.03   1012
# 8   4.973280   7.103322  144.50   1216
# 9   5.328556   6.639876  206.14    765

# %%
## forecast based on a given price elasticity (the slope of the linear regression)
## and based on a forecast price, number of rooms demanded and capacity
## this uses the slope for calculating the price elasticity
## increments from %200 to -%200 price change to find the max of P*Q

def forecast(slope,capacity,start_price,start_quantity):
        change_price = 2
        increment = 0.0005
        max_rev = [0,0,0]
        while change_price > -2:
                price = start_price*(1 + change_price)
                quantity = (1+(slope*change_price))*start_quantity
                rev = price*quantity
                if quantity <= capacity:
                        #print rev, price, quantity
                        if rev > max_rev[0]:
                                max_rev = [ rev, price, quantity ]
                change_price -= increment

        return max_rev[1]

# %%
## forecast based on the intercept and slope from the linear regression
## uses the function Q = exp(intercept+slope*log(P)) to maximize Q*P incrementing
## from P = 1000 downwards until Q exceeds capacity

def forecast2(intercept, slope, capacity):
    rooms = 0
    max_rev = [0,0,0]
    price = 1000
    while rooms <= capacity:
        rooms = exp(intercept+slope*log(price))
        rev = price * rooms
        if rev > max_rev[0] and rooms <= 1100:
            max_rev = [rev, price, rooms]
        price -= 1
    return max_rev[1]

# %%
## weekday price
print forecast(wd_slope,1100,200,1000)
print forecast2(wd_intercept,wd_slope,1100)
# Out:
# 188.7
# 149

# %%
## weekend price
print forecast(we_slope,1100,200,1000)
print forecast2(we_intercept,we_slope,1100)
# Out:
# 186.1
# 164
